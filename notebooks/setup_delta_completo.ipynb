# %% [markdown]
# # Setup Completo Delta Lake + S3A
#
# Este notebook baixa os JARs necessários e configura tudo automaticamente.

# %%
# CÉLULA 1: Executar setup completo
# Este script baixa os JARs e cria a Spark Session

exec(open('setup_spark_with_jars.py').read())

# %%
# CÉLULA 2: Executar setup do Delta Lake
# Este script converte os dados Parquet em Delta Lake

print("\n" + "=" * 80)
print("EXECUTANDO SETUP DO DELTA LAKE")
print("=" * 80)

# Executar o script de setup
exec(open('delta_setup_spark.py').read())
